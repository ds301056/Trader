# %%
import sys
sys.path.append("../") #make the file look above teh exploration folder into the code folder
import pandas as pd
import plotly.graph_objects as go
import datetime as dt
from plotting import CandlePlot

# %%
from infrastructure.instrument_collection import instrumentCollection as ic# Import the instrumentCollection instance from the infrastructure/instrument_collection.py file

# %%
pair = "GBP_JPY"
granularity="H4"
df = pd.read_pickle(f"../data/{pair}_{granularity}.pkl")
MA_LIST = [10, 20, 50, 100, 200]

# %%
df_ma = df[['time', 'mid_o', 'mid_h', 'mid_l', 'mid_c']].copy()

# %%
df_ma.head()
# Out:
#                        time    mid_o    mid_h    mid_l    mid_c
# 0 2021-06-28 01:00:00+00:00  153.780  153.796  153.596  153.708
# 1 2021-06-28 05:00:00+00:00  153.712  154.230  153.666  154.180
# 2 2021-06-28 09:00:00+00:00  154.178  154.228  153.898  154.102
# 3 2021-06-28 13:00:00+00:00  154.104  154.206  153.450  153.495
# 4 2021-06-28 17:00:00+00:00  153.498  153.567  153.390  153.544

# %%
for ma in MA_LIST:
    df_ma[f'MA_{ma}'] = df_ma.mid_c.rolling(window=ma).mean()
df_ma.dropna(inplace=True)
df_ma.reset_index(inplace=True, drop=True)

# %%
df_plot = df_ma.iloc[:500]

# %%
cp = CandlePlot(df_plot)

# %%
traces = [ f"MA_{x}" for x in MA_LIST ]

# %%
cp.show_plot(line_traces = traces)

# %%
MA_S = "MA_50"
MA_L = "MA_200"
BUY = 1
SELL = -1
NONE= 0

# %%
df_an = df_ma[['time', 'mid_o', 'mid_h', 'mid_l', 'mid_c', MA_S, MA_L]].copy()

# %%
df_an.head(30)
# Out:
#                         time    mid_o    mid_h    mid_l    mid_c      MA_50  \
# 0  2021-08-12 05:00:00+00:00  153.130  153.202  152.976  152.987  152.56790
# 1  2021-08-12 09:00:00+00:00  152.990  153.112  152.870  152.954  152.57742
# 2  2021-08-12 13:00:00+00:00  152.956  152.990  152.538  152.538  152.57522
# 3  2021-08-12 17:00:00+00:00  152.540  152.592  152.334  152.491  152.58208
# 4  2021-08-12 21:00:00+00:00  152.462  152.638  152.428  152.498  152.59588
# 5  2021-08-13 01:00:00+00:00  152.496  152.548  152.416  152.522  152.61074
# 6  2021-08-13 05:00:00+00:00  152.524  152.529  152.070  152.178  152.61674
# 7  2021-08-13 09:00:00+00:00  152.180  152.474  152.082  152.402  152.63050
# 8  2021-08-13 13:00:00+00:00  152.404  152.464  152.022  152.082  152.63494
# 9  2021-08-13 17:00:00+00:00  152.079  152.160  151.930  152.019  152.63932
# 10 2021-08-15 21:00:00+00:00  152.039  152.208  151.674  151.748  152.63852
# 11 2021-08-16 01:00:00+00:00  151.745  151.810  151.496  151.636  152.63688
# 12 2021-08-16 05:00:00+00:00  151.632  151.676  151.298  151.520  152.63588
# 13 2021-08-16 09:00:00+00:00  151.522  151.785  151.354  151.565  152.62878
# 14 2021-08-16 13:00:00+00:00  151.567  151.592  150.926  151.250  152.61122
# 15 2021-08-16 17:00:00+00:00  151.252  151.275  151.138  151.260  152.60414
# 16 2021-08-16 21:00:00+00:00  151.271  151.343  151.100  151.136  152.58272
# 17 2021-08-17 01:00:00+00:00  151.139  151.165  150.991  151.104  152.56348
# 18 2021-08-17 05:00:00+00:00  151.106  151.181  150.452  150.945  152.53582
# 19 2021-08-17 09:00:00+00:00  150.948  150.992  150.558  150.868  152.50640
# 20 2021-08-17 13:00:00+00:00  150.870  150.884  150.359  150.374  152.46364
# 21 2021-08-17 17:00:00+00:00  150.370  150.647  150.366  150.610  152.42778
# 22 2021-08-17 21:00:00+00:00  150.571  150.633  150.389  150.490  152.37994
# 23 2021-08-18 01:00:00+00:00  150.487  150.858  150.444  150.644  152.33458
# 24 2021-08-18 05:00:00+00:00  150.642  150.892  150.522  150.821  152.29262
# 25 2021-08-18 09:00:00+00:00  150.818  151.262  150.718  151.250  152.26002
# 26 2021-08-18 13:00:00+00:00  151.247  151.284  151.046  151.217  152.22848
# 27 2021-08-18 17:00:00+00:00  151.219  151.412  150.930  150.992  152.18664
# 28 2021-08-18 21:00:00+00:00  150.986  151.139  150.946  151.051  152.14970
# 29 2021-08-19 01:00:00+00:00  151.054  151.218  151.012  151.168  152.11438
#
#         MA_200
# 0   152.418420
# 1   152.414650
# 2   152.406440
# 3   152.398385
# 4   152.393400
# 5   152.388290
# 6   152.383010
# 7   152.378430
# 8   152.373675
# 9   152.368710
# 10  152.362525
# 11  152.355705
# 12  152.347475
# 13  152.340100
# 14  152.332210
# 15  152.322690
# 16  152.311830
# 17  152.298935
# 18  152.286530
# 19  152.273310
# 20  152.257590
# 21  152.241420
# 22  152.225925
# 23  152.211535
# 24  152.197465
# 25  152.185375
# 26  152.174810
# 27  152.163150
# 28  152.150745
# 29  152.139095

# %%
df_an['DELTA'] = df_an.MA_50 - df_an.MA_200
df_an['DELTA_PREV'] = df_an.DELTA.shift(1)

# %%
def is_trade(row):
    if row.DELTA >= 0 and row.DELTA_PREV < 0:
        return BUY
    elif row.DELTA < 0 and row.DELTA_PREV >= 0:
        return SELL
    return NONE

# %%
df_an['TRADE'] = df_an.apply(is_trade, axis=1)

# %%
df_trades = df_an[df_an.TRADE != NONE].copy()

# %%
df_trades.head()
# Out:
#                          time    mid_o    mid_h    mid_l    mid_c      MA_50  \
# 28  2021-08-18 21:00:00+00:00  150.986  151.139  150.946  151.051  152.14970
# 123 2021-09-09 17:00:00+00:00  152.015  152.021  151.750  151.828  151.77846
# 165 2021-09-20 17:00:00+00:00  149.270  149.544  149.182  149.402  151.57646
# 254 2021-10-11 13:00:00+00:00  154.175  154.512  154.029  154.352  151.38858
# 389 2021-11-11 02:00:00+00:00  152.920  153.012  152.681  152.884  154.23446
#
#          MA_200     DELTA  DELTA_PREV  TRADE
# 28   152.150745 -0.001045    0.023490     -1
# 123  151.777910  0.000550   -0.015855      1
# 165  151.599845 -0.023385    0.012675     -1
# 254  151.356965  0.031615   -0.030855      1
# 389  154.252505 -0.018045    0.051735     -1

# %%
cp = CandlePlot(df_an.iloc[115:280])
cp.show_plot(line_traces=[MA_S, MA_L])

# %%
ic.LoadInstruments("../data")

# %%
ic.instruments_dict[pair]
# Out:
# {'name': 'GBP_JPY', 'ins_type': 'CURRENCY', 'displayName': 'GBP/JPY', 'pipLocation': 0.01, 'tradeUnitsPrecision': 0, 'marginRate': 0.05}

# %%
df_trades.shape
# Out:
# (32, 10)

# %%
ins_data = ic.instruments_dict[pair]

# %%
df_trades.head()
# Out:
#                          time    mid_o    mid_h    mid_l    mid_c      MA_50  \
# 28  2021-08-18 21:00:00+00:00  150.986  151.139  150.946  151.051  152.14970
# 123 2021-09-09 17:00:00+00:00  152.015  152.021  151.750  151.828  151.77846
# 165 2021-09-20 17:00:00+00:00  149.270  149.544  149.182  149.402  151.57646
# 254 2021-10-11 13:00:00+00:00  154.175  154.512  154.029  154.352  151.38858
# 389 2021-11-11 02:00:00+00:00  152.920  153.012  152.681  152.884  154.23446
#
#          MA_200     DELTA  DELTA_PREV  TRADE
# 28   152.150745 -0.001045    0.023490     -1
# 123  151.777910  0.000550   -0.015855      1
# 165  151.599845 -0.023385    0.012675     -1
# 254  151.356965  0.031615   -0.030855      1
# 389  154.252505 -0.018045    0.051735     -1

# %%
df_trades['DIFF'] = df_trades.mid_c.diff().shift(-1)
df_trades.fillna(0, inplace=True)

# %%
df_trades['GAIN'] = df_trades['DIFF'] / ins_data.pipLocation
df_trades['GAIN'] = df_trades['GAIN'] * df_trades['TRADE']

# %%
df_trades.GAIN.sum()
# Out:
# -6694.700000000008

# %%
df_trades['GAIN_C'] = df_trades['GAIN'].cumsum()

# %%
cp = CandlePlot(df_trades, candles=False)
cp.show_plot(line_traces=['GAIN_C'])
